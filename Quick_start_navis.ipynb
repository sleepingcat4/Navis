# %%
# !pip install navis[all] -U --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 23.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 32.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.0/294.0 kB 28.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.5/682.5 kB 55.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.4/206.4 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.9/267.9 kB 30.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 98.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.1/237.1 kB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 420.5/420.5 MB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 790.1/790.1 kB 48.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 67.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 52.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.7/326.7 kB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 110.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 938.9/938.9 kB 69.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 116.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 92.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.4/275.4 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 23.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 133.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 126.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 115.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.8/215.8 kB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 102.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 77.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 MB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.2/729.2 kB 60.7 MB/s eta 0:00:00
#   Building wheel for posix-ipc (setup.py) ... done

# %%
import navis

n = navis.example_neurons(n=1, kind='skeleton')
n
# Out:
# type                                             navis.TreeNeuron
# name                                                    DA1_lPN_R
# id                                                     1734350788
# n_nodes                                                      4465
# n_connectors                                                 2705
# n_branches                                                    599
# n_leafs                                                       618
# cable_length                                           266476.875
# soma                                                       [4177]
# units                                                 8 nanometer
# created_at                             2023-07-30 08:35:25.886943
# id                                                     1734350788
# origin          /usr/local/lib/python3.10/dist-packages/navis/...
# dtype: object

# %%
n.nodes.head()
# Out:
#    node_id label        x        y        z     radius  parent_id  type
# 0        1     0  15784.0  37250.0  28062.0  10.000000         -1  root
# 1        2     0  15764.0  37230.0  28082.0  18.284300          1  slab
# 2        3     0  15744.0  37190.0  28122.0  34.721401          2  slab
# 3        4     0  15744.0  37150.0  28202.0  34.721401          3  slab
# 4        5     0  15704.0  37130.0  28242.0  34.721401          4  slab

# %%
help(navis.TreeNeuron.root)
# Out:
# Help on property:
#
#     Root node(s).

# %%
help(navis.TreeNeuron.downsample)
# Out:
# Help on function downsample in module navis.core.skeleton:
#
# downsample(self, factor=5, inplace=False, **kwargs)
#     Downsample the neuron by given factor.
#
#     Parameters
#     ----------
#     factor :                int, optional
#                             Factor by which to downsample the neurons.
#                             Default = 5.
#     inplace :               bool, optional
#                             If True, operation will be performed on
#                             itself. If False, operation is performed on
#                             copy which is then returned.
#     **kwargs
#                             Additional arguments passed to
#                             :func:`~navis.downsample_neuron`.
#
#     See Also
#     --------
#     :func:`~navis.downsample_neuron`
#         Base function. See for details and examples.

# %%
# Downsample a copy, leaving the original unchanged
# (this is the default for almost all functions)
n_ds = n.downsample(10, inplace=False)

# Downsample the original neuron
n_ds2 = n.copy()
n_ds2.downsample(10, inplace=True)

n_ds2
# Out:
# type                                             navis.TreeNeuron
# name                                                    DA1_lPN_R
# id                                                     1734350788
# n_nodes                                                      1304
# n_connectors                                                 2705
# n_branches                                                    599
# n_leafs                                                       618
# cable_length                                         247213.90625
# soma                                                       [4177]
# units                                                 8 nanometer
# created_at                             2023-07-30 08:35:25.886943
# id                                                     1734350788
# origin          /usr/local/lib/python3.10/dist-packages/navis/...
# dtype: object

# %%
n_ds = navis.downsample_neuron(n, downsampling_factor=10, inplace=False)
n_ds
# Out:
# type                                             navis.TreeNeuron
# name                                                    DA1_lPN_R
# id                                                     1734350788
# n_nodes                                                      1304
# n_connectors                                                 2705
# n_branches                                                    599
# n_leafs                                                       618
# cable_length                                         247213.90625
# soma                                                       [4177]
# units                                                 8 nanometer
# created_at                             2023-07-30 08:35:25.886943
# id                                                     1734350788
# origin          /usr/local/lib/python3.10/dist-packages/navis/...
# dtype: object

# %%
nl = navis.example_neurons(n=3, kind='skeleton')
nl
# Out:
# <class 'navis.core.neuronlist.NeuronList'> containing 3 neurons (875.1KiB)
#                type       name          id  n_nodes  n_connectors  n_branches  \
# 0  navis.TreeNeuron  DA1_lPN_R  1734350788     4465          2705         599
# 1  navis.TreeNeuron  DA1_lPN_R  1734350908     4847          3042         735
# 2  navis.TreeNeuron  DA1_lPN_R   722817260     4332          3136         633
#
#    n_leafs  cable_length    soma        units                  created_at  \
# 0      618  266476.87500  [4177]  8 nanometer  2023-07-30 08:36:45.809018
# 1      761  304332.65625     [6]  8 nanometer  2023-07-30 08:36:45.829874
# 2      656  274703.37500    None  8 nanometer  2023-07-30 08:36:45.968177
#
#                                               origin
# 0  /usr/local/lib/python3.10/dist-packages/navis/...
# 1  /usr/local/lib/python3.10/dist-packages/navis/...
# 2  /usr/local/lib/python3.10/dist-packages/navis/...

# %%
nl[0]
# Out:
# type                                             navis.TreeNeuron
# name                                                    DA1_lPN_R
# id                                                     1734350788
# n_nodes                                                      4465
# n_connectors                                                 2705
# n_branches                                                    599
# n_leafs                                                       618
# cable_length                                           266476.875
# soma                                                       [4177]
# units                                                 8 nanometer
# created_at                             2023-07-30 08:36:45.809018
# id                                                     1734350788
# origin          /usr/local/lib/python3.10/dist-packages/navis/...
# dtype: object

# %%
nl.cable_length
# Out:
# array([266476.88, 304332.66, 274703.38], dtype=float32)

# %%
nl_ds = nl.downsample(10, inplace=False)

nl_ds
# Out:
# <class 'navis.core.neuronlist.NeuronList'> containing 3 neurons (670.4KiB)
#                type       name          id  n_nodes  n_connectors  n_branches  \
# 0  navis.TreeNeuron  DA1_lPN_R  1734350788     1304          2705         599
# 1  navis.TreeNeuron  DA1_lPN_R  1734350908     1558          3042         735
# 2  navis.TreeNeuron  DA1_lPN_R   722817260     1346          3136         633
#
#    n_leafs  cable_length    soma        units                  created_at  \
# 0      618  247213.90625  [4177]  8 nanometer  2023-07-30 08:36:45.809018
# 1      761  282457.12500     [6]  8 nanometer  2023-07-30 08:36:45.829874
# 2      656  254727.56250    None  8 nanometer  2023-07-30 08:36:45.968177
#
#                                               origin
# 0  /usr/local/lib/python3.10/dist-packages/navis/...
# 1  /usr/local/lib/python3.10/dist-packages/navis/...
# 2  /usr/local/lib/python3.10/dist-packages/navis/...

# %%
fig = nl.plot3d()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="12aecc1c-b17f-4786-ab05-ad494ddffabb" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12aecc1c-b17f-4786-ab05-ad494ddffabb")) {                    Plotly.newPlot(                        "12aecc1c-b17f-4786-ab05-ad494ddffabb",                        [{"hoverinfo":"none","hovertext":" ","legendgroup":"1734350788","line":{"color":"rgb(219,94,86)","width":2},"mode":"lines","name":"DA1_lPN_R (1734350788)","showlegend":true,"x":[3964.0,3964.0,3883.85009765625,3955.050048828125,4024.0,4024.0,4024.0,4044.0,4044.0,4064.0,4104.0,4104.0,4124.0,4184.0,4224.0,4264.0,4304.0,4344.0,4364.0,4404.0,4444.0,4464.0,4504.0,4524.0,4564.0,4604.0,4644.0,4684.0,4704.0,4744.0,4844.0,4969.91015625,5044.0,5024.0,5004.0,5004.0,5004.0,4984.0,4956.72998046875,4884.0,4884.0,4884.0,4901.14013671875,4884.0,4884.0,4864.0,4904.0,4964.0,4944.0,4947.2900390625,5004.0,5024.0,5005.580078125,5004.0,5044.0,5044.0,5064.0,5104.0,5124.0,5168.7099609375,5270.89990234375,5444.0,5564.0,5684.0,5764.0,5864.0,5964.0,6064.0,6069.7099609375,6164.0,6264.0,6384.0,6504.0,6644.0,6764.0,6